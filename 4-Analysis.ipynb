# %%
#Importing Libraries

import pandas as pd
import numpy as np

from chart_studio import plotly
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected = True)
import plotly.graph_objs as go
import plotly.express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Importing the csv files

inspections_fact = pd.read_csv('inspections_fact.csv')
establishments_dimension = pd.read_csv('establishments_dimension.csv')
inspection_point_dimension = pd.read_csv('inspection_point_dimension.csv')
violations_dimension = pd.read_csv('violations_dimension.csv')

# %%
violations_dimension.head()

# %%
### Analysis on the what the top Inspection comments are : To understand the most common problems.

# Checking count of unique inspector comments. 
len(violations_dimension['Inspector_Comments'].unique())

#The inspector comments descriptions are very specific. There are 97358 unique comments
# Out:
# 97358

# %%
# Since inspector comments are unique we are selecting only first 200 characters from the string for ease of reading and getting the gist.

violations_dimension['Resized_Inspector_Comments'] = violations_dimension['Inspector_Comments'].str[:200]
violations_dimension.drop('Inspector_Comments',1,inplace=True)

comments_data = violations_dimension[['Resized_Inspector_Comments']].groupby(['Resized_Inspector_Comments']).agg({'Resized_Inspector_Comments':'count'})
comments_data.columns = ['Counts']
comments_data.reset_index(inplace=True)
comments_data.columns = ['Resized_Inspector_Comments','Counts']
comments_data.sort_values('Counts',ascending=True,inplace=True)
# Out:
# C:\Users\Ambika\AppData\Local\Temp/ipykernel_15160/2233786040.py:4: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
fig1 = px.bar(comments_data[comments_data.shape[0]-10:], x='Counts', y='Resized_Inspector_Comments', orientation='h', height=500, width=1500)
fig1.update_layout(xaxis_title="Number of Violations", yaxis_title="Inspection Comments", title="Common Health Violations in Chicago")
fig1.update_traces(marker_color='darkcyan')
fig1.show()
# Out:
# <div>                            <div id="64a0bf3d-f178-48d9-8a14-8d3b85c461a2" class="plotly-graph-div" style="height:500px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64a0bf3d-f178-48d9-8a14-8d3b85c461a2")) {                    Plotly.newPlot(                        "64a0bf3d-f178-48d9-8a14-8d3b85c461a2",                        [{"alignmentgroup":"True","hovertemplate":"Counts=%{x}<br>Resized_Inspector_Comments=%{y}<extra></extra>","legendgroup":"","marker":{"color":"darkcyan","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[339,412,591,591,609,1013,1177,1197,1387,2581],"xaxis":"x","y":["Corrected","Containers And Utensils Shall Be Inverted, Covered, Or Otherwise Protected From Contamination Until Used.  All Single-Service Drinking Straws And Containers Shall Be Discarded Immediately After Use.  ","Food Not Protected During Preparation, Observed Multiple Food Handlers  Extensively Handling Food (Preparing And Assembling Pasta Salads, Cutting/Slicing Vegetables And Fruits Inside Tent Which Is An ","Corrected.","0","Stillfound Evidence Of Rat Activity On Premises. Over 15 Rat Dropings Found In 1St And 2Nd Floor. Must Eliminate Rat Activity And Clean Affected Areas.","Observed Rat Droppings In Shelve Areas. Must Remove Droppings, Clean And Sanitize Affected Areas And Have Service From Pest Control. Remove Foul Odors.","Violation Corrected.","Garbage Bins Overloaded, Not Allowing For Proper Closure. Remove Foul Smell. Toilets Should Have Adequate Ventilation. Next Inspection In One Month","All Necessary Control Measures Shall Be Used To Effectively Minimize Or Eliminate The Presence Of Rodents, Roaches, And Other Vermin And Insects On The Premises Of All Food Establishments, In Food-Tra"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed795 ...

# %%
#Analysis on the type of Facilities

#Extracting all the different types of facilities and ploting them as a pie chart. Clubbing facilities with less than 1% as Others

facility_types = establishments_dimension['Facility_Type'].value_counts().keys().tolist()
facility_count = establishments_dimension['Facility_Type'].value_counts().tolist()

final_types = []
final_count = []
others_count = 0
one_percent = 0.01 * establishments_dimension.shape[0]
for count, facility_type in zip(facility_count, facility_types):
    if count > one_percent:
        final_types.append(facility_type)
        final_count.append(count)
    else:
        others_count += count
        
final_types.append('Others')
final_count.append(others_count)

# figure
fig = {
    "data": [{
        "values": final_count,
        "labels": final_types,
        "hoverinfo": "label+percent",
        "hole": .5,
        "type": "pie"
        },
    ],
    "layout": {
        "title": "Types of facilities",
        "width": 800,
        "height": 800
    }
}

iplot(fig)
# Out:
# <div>                            <div id="fde490cc-1c9d-4bcc-9a51-81356dbe0b39" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fde490cc-1c9d-4bcc-9a51-81356dbe0b39")) {                    Plotly.newPlot(                        "fde490cc-1c9d-4bcc-9a51-81356dbe0b39",                        [{"hole":0.5,"hoverinfo":"label+percent","labels":["Restaurant","Grocery Store","School Cafeteria","Daycare","Bakery","Children'S Services Facility","Others"],"values":[78010,16059,8241,3713,1762,1556,5162],"type":"pie"}],                        {"height":800,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo ...
#
# var gd = document.getElementById('fde490cc-1c9d-4bcc-9a51-81356dbe0b39');
# var x = new MutationObserver(function (mutations, observ

# %%
#Analysis on the number of facilitis that passed the inspection and the one's that did not. 

data = [
    go.Bar(
        x = inspections_fact['Results'].value_counts().keys().tolist(),
        y = inspections_fact['Results'].value_counts().tolist(),
        marker = dict(
            color = [
                'rgb(0,100, 0)', 
                'rgb(0,100, 0)',
                'rgb(255, 0, 0)',
                'rgb(255, 0, 0)',
                'rgb(255, 0, 0)'
            ]
        )
    )
]

layout = go.Layout(
    title = 'Inspection Results',
)

fig = go.Figure(data = data, layout = layout)
iplot(fig, filename = 'inspections')
# Out:
# <div>                            <div id="1f8c5ee9-9857-4bd2-94b6-d0fbdd694ec9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f8c5ee9-9857-4bd2-94b6-d0fbdd694ec9")) {                    Plotly.newPlot(                        "1f8c5ee9-9857-4bd2-94b6-d0fbdd694ec9",                        [{"marker":{"color":["rgb(0,100, 0)","rgb(0,100, 0)","rgb(255, 0, 0)","rgb(255, 0, 0)","rgb(255, 0, 0)"]},"x":["Pass","Fail","Pass W/ Conditions","No Entry","Out Of Business","Not Ready"],"y":[75852,24988,13422,255,33,21],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scatterge ...
#
# var gd = document.getElementById('1f8c5ee9-9857-4bd2-94b6-d0fbdd694ec9');
# var x = new MutationObserver(function (mutations, observer) {{

# %%
#Analysis on the top facilities that are categorised as high risk

high_risk=establishments_dimension[establishments_dimension.Risk=='Risk 1 (High)']
high_risk.head()

data = [
    go.Bar(
        x = establishments_dimension['Facility_Type'].value_counts()[:10].keys().tolist(),
        y = establishments_dimension['Facility_Type'].value_counts()[:10].tolist(),
        marker = dict(
            color = [
                'rgb(0,100, 0)', 
                'rgb(0,100, 0)',
                'rgb(255, 0, 0)',
                'rgb(255, 0, 0)',
                'rgb(255, 0, 0)'
            ]
        )
    )
]

layout = go.Layout(
    title = 'Top 10 Facility Type with High risk',
)

fig = go.Figure(data = data, layout = layout)
iplot(fig, filename = 'highrisk')
# Out:
# <div>                            <div id="7bf3e3b8-35a0-4bf6-b9d4-df6daf18bf00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bf3e3b8-35a0-4bf6-b9d4-df6daf18bf00")) {                    Plotly.newPlot(                        "7bf3e3b8-35a0-4bf6-b9d4-df6daf18bf00",                        [{"marker":{"color":["rgb(0,100, 0)","rgb(0,100, 0)","rgb(255, 0, 0)","rgb(255, 0, 0)","rgb(255, 0, 0)"]},"x":["Restaurant","Grocery Store","School Cafeteria","Daycare","Bakery","Children'S Services Facility","Long Term Care","Catering","Liquor Store","Wholesale"],"y":[78010,16059,8241,3713,1762,1556,794,626,459,381],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scatter ...
#
# var gd = document.getElement

# %%
#Analysis of top 20 facility and their results.

high_risk = establishments_dimension[establishments_dimension.Risk=='Risk 1 (High)']
high_risk.head()

data = [
    go.Bar(
        x = establishments_dimension['Facility_Type'].value_counts()[:20].keys().tolist(),
        y = inspections_fact['Results'],
        marker = dict(
            color = [
                'rgb(0,100, 0)', 
                'rgb(0,100, 0)',
                'rgb(255, 0, 0)',
                'rgb(255, 0, 0)',
                'rgb(255, 0, 0)'
            ]
        )
    )
]

layout = go.Layout(
    title = 'Top 10 Facility Type and their corresponding inspection results',
)

fig = go.Figure(data = data, layout = layout)
iplot(fig, filename = 'highrisk')
# Out:
# <div>                            <div id="7a293494-d939-47a1-abff-f57c8046bbb6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a293494-d939-47a1-abff-f57c8046bbb6")) {                    Plotly.newPlot(                        "7a293494-d939-47a1-abff-f57c8046bbb6",                        [{"marker":{"color":["rgb(0,100, 0)","rgb(0,100, 0)","rgb(255, 0, 0)","rgb(255, 0, 0)","rgb(255, 0, 0)"]},"x":["Restaurant","Grocery Store","School Cafeteria","Daycare","Bakery","Children'S Services Facility","Long Term Care","Catering","Liquor Store","Wholesale","Golden Diner","Mobile Food Dispenser","Hospital","Mobile Food Preparer","Tavern","Banquet Hall","Gas Station/Mini Mart","Convenience Store","Kiosk","Live Poultry"],"y":["Fail","Fail","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Fail","Fail","Fail","Pass W/ Conditions","Pass","Fail","Fail","Fail","Pass W/ Conditions","Fail","Fail","Fail","Fail","Pass W/ Conditions","Fail","Fail","Fail","Fail","Fail","Pass","Fail","Fail","Fail","Fail","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Fail","Fail","Fail","Pass W/ Conditions","Fail","Fail","Fail","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Fail","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Fail","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass","Pass W/ Conditions","Fail","Pass W/ Conditions","Fail","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Pass","Pass W/ Conditions","Fail","Fail","Fail","Fail","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Fail","Pass W/ Conditions","Fail","Fail","Pass W/ Conditions","Fail","Pass W/ Conditions","Fail","Fail","Pass W/ Conditions","Fail","Fail","Fail","Fail","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Pass W/ Conditions","Fail","Fail","Pass W/ Conditions","Fail","Fail","Pass","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Fail","Pass","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Fail","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Pass W/ Conditions","Fail","Fail","Fail","Fail","Fail","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Fail","Fail","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Pass W/ Conditions","Fail","Pass W/ Conditions","Fail","Pass W/ Conditions","Pass W/ Conditions","Fail","Fail","Pass W/ Conditions","Pass W/ Conditions","Pass ...
